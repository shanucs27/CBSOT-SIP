# %% [markdown]
# ## **Machine Learning**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (5634, 30)

# %%
X_test.shape
# Out:
# (1409, 30)

# %%
Y_train.shape
# Out:
# (5634,)

# %%
Y_test.shape
# Out:
# (1409,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=100,random_state=42)

# %%
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=rf_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(Y_test,y_pred)

# %%
accuracy
# Out:
# 0.7856635911994322

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[902, 107],
#        [195, 205]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1009
#            1       0.66      0.51      0.58       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# ## **Approach 1 Handle Class Imbalance**

# %%
rf_balanced=RandomForestClassifier(n_estimators=100,random_state=42,class_weight='balanced')

# %%
rf_balanced.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred_bal=rf_balanced.predict(X_test)

# %%
y_pred_bal
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
accuracy_new=accuracy_score(Y_test,y_pred_bal)
accuracy_new
# Out:
# 0.7920511000709723

# %%
cm_balanced=confusion_matrix(Y_test,y_pred_bal)
cm_balanced
# Out:
# array([[907, 102],
#        [191, 209]])

# %%
print(classification_report(Y_test,y_pred_bal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1009
#            1       0.67      0.52      0.59       400
#
#     accuracy                           0.79      1409
#    macro avg       0.75      0.71      0.72      1409
# weighted avg       0.78      0.79      0.78      1409

# %% [markdown]
# ## **Approach 2 Hyper Paramater Tuning**

# %%
rf_tuned=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')

# %%
rf_tuned.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=300,
#                        random_state=42)

# %%
y_pred_tuned=rf_tuned.predict(X_test)

# %%
y_pred_tuned
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
accuracy_new_tuned=accuracy_score(Y_test,y_pred_tuned)
accuracy_new_tuned
# Out:
# 0.7828246983676366

# %%
cm_balanced=confusion_matrix(Y_test,y_pred_tuned)
cm_balanced
# Out:
# array([[804, 205],
#        [101, 299]])

# %%
print(classification_report(Y_test,y_pred_tuned))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.59      0.75      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %% [markdown]
# ## **Approach 3 : Feature Importance Anaylysis**

# %%
import pandas as pd
features_importance=pd.DataFrame({'features':X.columns,'Importance':rf_tuned.feature_importances_})
sorted=features_importance.sort_values(by='Importance',ascending=False)
sorted
# Out:
#                                   features  Importance
# 0                            Tenure Months    0.179069
# 2                            Total Charges    0.136460
# 25                       Contract_Two year    0.102861
# 1                          Monthly Charges    0.093681
# 6                           Dependents_Yes    0.068517
# 10            Internet Service_Fiber optic    0.060228
# 28         Payment Method_Electronic check    0.046732
# 24                       Contract_One year    0.036682
# 13                     Online Security_Yes    0.029356
# 19                        Tech Support_Yes    0.021106
# 26                   Paperless Billing_Yes    0.018064
# 5                              Partner_Yes    0.015846
# 12     Online Security_No internet service    0.014973
# 18        Tech Support_No internet service    0.014799
# 22    Streaming Movies_No internet service    0.014360
# 16   Device Protection_No internet service    0.012985
# ...

# %%
X_selected=X.drop(['Phone Service_Yes','Multiple Lines_No phone service',],axis=1)

# %%
X_selected_train,X_selected_test,Y_train_sel,Y_test_sel=train_test_split(X_selected,Y,test_size=0.2,random_state=42)

# %%
rf_selected=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
rf_selected.fit(X_selected_train,Y_train_sel)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, n_estimators=300,
#                        random_state=42)

# %%
y_pred_sel=rf_selected.predict(X_selected_test)

# %%
print(classification_report(Y_test_sel,y_pred_sel))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1009
#            1       0.60      0.74      0.66       400
#
#     accuracy                           0.78      1409
#    macro avg       0.74      0.77      0.75      1409
# weighted avg       0.80      0.78      0.79      1409

# %% [markdown]
# ## **N_estimators and Depth Combinations**

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
max_depth_lst=[5,10,15,20]
n_estimators_lst=[100,200,300,400,500]
results=[]
for depth in max_depth_lst:
    for n_estimators in n_estimators_lst:
        rf=RandomForestClassifier(n_estimators=n_estimators,max_depth=depth,random_state=42,class_weight='balanced')
        rf.fit(X_train,Y_train)
        y_pred=rf.predict(X_test)
        accuracy=accuracy_score(Y_test,y_pred)
        recall=recall_score(Y_test,y_pred)
        precision=precision_score(Y_test,y_pred)
        f1=f1_score(Y_test,y_pred)
        results.append({"Trees":n_estimators,"Depth":depth,"Accuracy":accuracy,"Recall":recall,"Precision":precision,"F1":f1})
res=pd.DataFrame(results)
res=res.sort_values(by=['Recall','Accuracy'],ascending=False)
res
# Out:
#     Trees  Depth  Accuracy  Recall  Precision        F1
# 0     100      5  0.745919  0.8200   0.534202  0.646943
# 2     300      5  0.743790  0.8200   0.531605  0.645034
# 3     400      5  0.743790  0.8125   0.531915  0.642928
# 1     200      5  0.742370  0.8100   0.530278  0.640950
# 4     500      5  0.740951  0.8050   0.528736  0.638256
# 5     100     10  0.775727  0.7525   0.581081  0.655773
# 7     300     10  0.782825  0.7475   0.593254  0.661504
# 8     400     10  0.782825  0.7475   0.593254  0.661504
# 9     500     10  0.781405  0.7475   0.590909  0.660044
# 6     200     10  0.782115  0.7450   0.592445  0.660022
# 12    300     15  0.806246  0.6400   0.664935  0.652229
# 13    400     15  0.803407  0.6375   0.658915  0.648030
# 14    500     15  0.801987  0.6375   0.655527  0.646388
# 11    200     15  0.804826  0.6350   0.663185  0.648787
# 10    100     15  0.802697  0.6300   0.659686  0.644501
# 15    100     20  0.787793  0.5325   0.655385  0.587586
# ...

# %% [markdown]
# **Cross Validation**

# %%
from sklearn.model_selection import cross_val_score
final_model=RandomForestClassifier(n_estimators=300,max_depth=10,random_state=42,class_weight='balanced')
scores=cross_val_score(final_model,X,Y,cv=5,scoring='accuracy')
scores
# Out:
# array([0.76721079, 0.79772889, 0.76224273, 0.78551136, 0.78409091])

# %%
scores.mean()
# Out:
# np.float64(0.7793569343183432)

# %%
scores1=cross_val_score(final_model,X,Y,cv=5,scoring='recall')

# %%
scores1.mean()
# Out:
# np.float64(0.7335350030823931)

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
y_prob=rf_selected.predict_proba(X_selected_test)

# %%
churn_proba=y_prob[:,1]
fpr,tpr,threshold=roc_curve(Y_test,churn_proba)
aoc_score=roc_auc_score(Y_test,churn_proba)
print(aoc_score)
print(churn_proba)
# Out:
# 0.8570676412289395
# [0.71492307 0.32134306 0.25230247 ... 0.73541778 0.07141633 0.77408427]
